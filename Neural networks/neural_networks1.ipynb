# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

# Load the dataset
data = pd.read_csv(r"D:\Assignments\Neural networks\Alphabets_data.csv")

# Explore the dataset
print(data.head())
print(data.info())
print(data.describe())

# Check for missing values
print(data.isnull().sum())

# Handle missing values (if any)
data = data.dropna()

# Separate features and labels
X = data.drop("letter", axis=1)
y = data["letter"]

# Normalize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Encode the labels if they are not integers
if y.dtype == 'object':
    y = pd.factorize(y)[0]

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Check the shapes of the training and test sets
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)

# Convert labels to categorical if necessary
y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)

# Build the ANN model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(y_train_cat.shape[1], activation='softmax')  # Adjust output layer based on the number of classes
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train_cat, epochs=50, validation_split=0.2, batch_size=32)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test_cat)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
#   letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  xybar  \
# 0      T     2     8      3       5      1     8    13      0      6      6
# 1      I     5    12      3       7      2    10     5      5      4     13
# 2      D     4    11      6       8      6    10     6      2      6     10
# 3      N     7    11      6       6      3     5     9      4      6      4
# 4      G     2     1      3       1      1     8     6      6      6      6
#
#    x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# 0      10       8      0       8      0       8
# 1       3       9      2       8      4      10
# 2       3       7      3       7      3       9
# 3       4      10      6      10      2       8
# 4       5       9      1       7      5      10
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   letter  20000 non-null  object
#  1   xbox    20000 non-null  int64
#  2   ybox    20000 non-null  int64
#  3   width   20000 non-null  int64
#  4   height  20000 non-null  int64
#  5   onpix   20000 non-null  int64
#  6   xbar    20000 non-null  int64
#  7   ybar    20000 non-null  int64
#  8   x2bar   20000 non-null  int64
#  9   y2bar   20000 non-null  int64
#  10  xybar   20000 non-null  int64
#  11  x2ybar  20000 non-null  int64
#  12  xy2bar  20000 non-null  int64
#  13  xedge   20000 non-null  int64
#  14  xedgey  20000 non-null  int64
#  15  yedge   20000 non-null  int64
#  16  yedgex  20000 non-null  int64
# dtypes: int64(16), object(1)
# memory usage: 2.6+ MB
# None
#                xbox          ybox         width       height         onpix  \
# count  20000.000000  20000.000000  20000.000000  20000.00000  20000.000000
# mean       4.023550      7.035500      5.121850      5.37245      3.505850
# std        1.913212      3.304555      2.014573      2.26139      2.190458
# min        0.000000      0.000000      0.000000      0.00000      0.000000
# 25%        3.000000      5.000000      4.000000      4.00000      2.000000
# 50%        4.000000      7.000000      5.000000      6.00000      3.000000
# 75%        5.000000      9.000000      6.000000      7.00000      5.000000
# max       15.000000     15.000000     15.000000     15.00000     15.000000
#
#                xbar          ybar         x2bar         y2bar         xybar  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       6.897600      7.500450      4.628600      5.178650      8.282050
# std        2.026035      2.325354      2.699968      2.380823      2.488475
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        6.000000      6.000000      3.000000      4.000000      7.000000
# 50%        7.000000      7.000000      4.000000      5.000000      8.000000
# 75%        8.000000      9.000000      6.000000      7.000000     10.000000
# max       15.000000     15.000000     15.000000     15.000000     15.000000
#
#             x2ybar        xy2bar         xedge        xedgey         yedge  \
# count  20000.00000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       6.45400      7.929000      3.046100      8.338850      3.691750
# std        2.63107      2.080619      2.332541      1.546722      2.567073
# min        0.00000      0.000000      0.000000      0.000000      0.000000
# 25%        5.00000      7.000000      1.000000      8.000000      2.000000
# 50%        6.00000      8.000000      3.000000      8.000000      3.000000
# 75%        8.00000      9.000000      4.000000      9.000000      5.000000
# max       15.00000     15.000000     15.000000     15.000000     15.000000
#
#             yedgex
# count  20000.00000
# mean       7.80120
# std        1.61747
# min        0.00000
# 25%        7.00000
# 50%        8.00000
# 75%        9.00000
# max       15.00000
# letter    0
# xbox      0
# ybox      0
# width     0
# height    0
# onpix     0
# xbar      0
# ybar      0
# x2bar     0
# y2bar     0
# xybar     0
# x2ybar    0
# xy2bar    0
# xedge     0
# xedgey    0
# yedge     0
# yedgex    0
# dtype: int64
# (16000, 16) (4000, 16)
# (16000,) (4000,)
# Epoch 1/50
# C:\Users\Aniket\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2613 - loss: 2.6366 - val_accuracy: 0.6541 - val_loss: 1.2454
# Epoch 2/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6923 - loss: 1.0991 - val_accuracy: 0.7444 - val_loss: 0.9161
# Epoch 3/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7657 - loss: 0.8069 - val_accuracy: 0.7884 - val_loss: 0.7509
# Epoch 4/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8021 - loss: 0.6818 - val_accuracy: 0.8150 - val_loss: 0.6511
# Epoch 5/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step - accuracy: 0.8248 - loss: 0.5966 - val_accuracy: 0.8344 - val_loss: 0.5779
# Epoch 6/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - accuracy: 0.8449 - loss: 0.5292 - val_accuracy: 0.8487 - val_loss: 0.5230
# Epoch 7/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - accuracy: 0.8631 - loss: 0.4673 - val_accuracy: 0.8581 - val_loss: 0.4757
# Epoch 8/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8741 - loss: 0.4176 - val_accuracy: 0.8697 - val_loss: 0.4487
# Epoch 9/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8805 - loss: 0.4054 - val_accuracy: 0.8719 - val_loss: 0.4194
# Epoch 10/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8925 - loss: 0.3608 - val_accuracy: 0.8822 - val_loss: 0.3939
# Epoch 11/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8994 - loss: 0.3350 - val_accuracy: 0.8931 - val_loss: 0.3760
# Epoch 12/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - accuracy: 0.9056 - loss: 0.3118 - val_accuracy: 0.8881 - val_loss: 0.3650
# Epoch 13/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9092 - loss: 0.2980 - val_accuracy: 0.8966 - val_loss: 0.3461
# Epoch 14/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9177 - loss: 0.2768 - val_accuracy: 0.8972 - val_loss: 0.3331
# Epoch 15/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9166 - loss: 0.2580 - val_accuracy: 0.9034 - val_loss: 0.3317
# Epoch 16/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9212 - loss: 0.2538 - val_accuracy: 0.9078 - val_loss: 0.3101
# Epoch 17/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9262 - loss: 0.2376 - val_accuracy: 0.9022 - val_loss: 0.3048
# Epoch 18/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - accuracy: 0.9293 - loss: 0.2272 - val_accuracy: 0.9081 - val_loss: 0.3010
# Epoch 19/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9332 - loss: 0.2184 - val_accuracy: 0.9103 - val_loss: 0.2891
# Epoch 20/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - accuracy: 0.9368 - loss: 0.2096 - val_accuracy: 0.9178 - val_loss: 0.2780
# Epoch 21/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9352 - loss: 0.2037 - val_accuracy: 0.9112 - val_loss: 0.2789
# Epoch 22/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - accuracy: 0.9407 - loss: 0.1914 - val_accuracy: 0.9106 - val_loss: 0.2769
# Epoch 23/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - accuracy: 0.9445 - loss: 0.1871 - val_accuracy: 0.9147 - val_loss: 0.2616
# Epoch 24/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - accuracy: 0.9459 - loss: 0.1748 - val_accuracy: 0.9216 - val_loss: 0.2549
# Epoch 25/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9467 - loss: 0.1715 - val_accuracy: 0.9212 - val_loss: 0.2533
# Epoch 26/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - accuracy: 0.9510 - loss: 0.1583 - val_accuracy: 0.9259 - val_loss: 0.2473
# Epoch 27/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9512 - loss: 0.1565 - val_accuracy: 0.9219 - val_loss: 0.2508
# Epoch 28/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - accuracy: 0.9568 - loss: 0.1485 - val_accuracy: 0.9244 - val_loss: 0.2393
# Epoch 29/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - accuracy: 0.9567 - loss: 0.1480 - val_accuracy: 0.9237 - val_loss: 0.2375
# Epoch 30/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9571 - loss: 0.1358 - val_accuracy: 0.9266 - val_loss: 0.2341
# Epoch 31/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step - accuracy: 0.9609 - loss: 0.1328 - val_accuracy: 0.9253 - val_loss: 0.2347
# Epoch 32/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - accuracy: 0.9569 - loss: 0.1342 - val_accuracy: 0.9266 - val_loss: 0.2298
# Epoch 33/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9627 - loss: 0.1271 - val_accuracy: 0.9200 - val_loss: 0.2460
# Epoch 34/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - accuracy: 0.9604 - loss: 0.1307 - val_accuracy: 0.9259 - val_loss: 0.2260
# Epoch 35/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9626 - loss: 0.1179 - val_accuracy: 0.9303 - val_loss: 0.2215
# Epoch 36/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9615 - loss: 0.1227 - val_accuracy: 0.9312 - val_loss: 0.2162
# Epoch 37/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9620 - loss: 0.1191 - val_accuracy: 0.9278 - val_loss: 0.2346
# Epoch 38/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9636 - loss: 0.1140 - val_accuracy: 0.9328 - val_loss: 0.2217
# Epoch 39/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9667 - loss: 0.1063 - val_accuracy: 0.9262 - val_loss: 0.2420
# Epoch 40/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - accuracy: 0.9697 - loss: 0.1026 - val_accuracy: 0.9316 - val_loss: 0.2190
# Epoch 41/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - accuracy: 0.9661 - loss: 0.1033 - val_accuracy: 0.9306 - val_loss: 0.2186
# Epoch 42/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - accuracy: 0.9691 - loss: 0.0973 - val_accuracy: 0.9331 - val_loss: 0.2148
# Epoch 43/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9695 - loss: 0.0975 - val_accuracy: 0.9359 - val_loss: 0.2110
# Epoch 44/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - accuracy: 0.9732 - loss: 0.0964 - val_accuracy: 0.9291 - val_loss: 0.2146
# Epoch 45/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step - accuracy: 0.9699 - loss: 0.0907 - val_accuracy: 0.9350 - val_loss: 0.2106
# Epoch 46/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9718 - loss: 0.0876 - val_accuracy: 0.9337 - val_loss: 0.2212
# Epoch 47/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9717 - loss: 0.0940 - val_accuracy: 0.9356 - val_loss: 0.2071
# Epoch 48/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9767 - loss: 0.0818 - val_accuracy: 0.9347 - val_loss: 0.2148
# Epoch 49/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - accuracy: 0.9737 - loss: 0.0860 - val_accuracy: 0.9388 - val_loss: 0.2081
# Epoch 50/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - accuracy: 0.9758 - loss: 0.0789 - val_accuracy: 0.9350 - val_loss: 0.2089
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step - accuracy: 0.9349 - loss: 0.1993
# Test Accuracy: 93.70%
